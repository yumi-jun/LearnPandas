# %% [markdown]
# <a href="https://colab.research.google.com/github/yumi-jun/LearnPandas/blob/main/%ED%8C%90%EB%8B%A4%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas 객체

# %%
import pandas as pd
import numpy as np

#인덱스 지정
s=pd.Series([0,0.25,0.5,0.75,1.0],index=['a','b','c','d','e'])

s['c']

'b' in s
# Out:
# True

# %%
s.unique()
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
# 각 값들이 얼마씩 존재하는지
s.value_counts()
# Out:
# 0.00    1
# 0.25    1
# 0.50    1
# 0.75    1
# 1.00    1
# Name: count, dtype: int64

# %%
# isin: 위의 값들이 index 위치한 곳에 true 반환
s.isin([0.25,0.75])
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# dtype: bool

# %%
# 튜플 작성
pop_tuple={'용인시':1223,'시흥시':4444,'수원시':5555}
population = pd.Series(pop_tuple)
population
population['전유미':'전유진']
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # DataFrame

# %%
#누락값이 NaN 으로 처리됨! 이것이 Pandas 의 장점, 누락값의 처리가 확실하다.
pd.DataFrame([{'A':2,'B':3,'C':1},{'A':1,'B':3,'D':5}])
# Out:
#    A  B    C    D
# 0  2  3  1.0  NaN
# 1  1  3  NaN  5.0

# %%
pd.DataFrame(np.random.rand(5,5), columns=['A','B','C','D','E'],index=[1,2,3,4,5])
# Out:
#           A         B         C         D         E
# 1  0.845197  0.716900  0.262699  0.136970  0.456392
# 2  0.528697  0.694993  0.244670  0.852945  0.908388
# 3  0.731214  0.297147  0.636796  0.209915  0.879309
# 4  0.790017  0.773442  0.360427  0.871427  0.652343
# 5  0.406407  0.399741  0.175440  0.311057  0.971829

# %%
male_tuple={'용인시':1234,'시흥시':1233,'수원시':444}
male = pd.Series(male_tuple)
male['용인시']
# Out:
# 1234

# %%
female_tuple={'용인시':3334,'시흥시':1234,'수원시':2345}
female = pd.Series(male_tuple)
female['용인시']
# Out:
# 1234

# %%
korea_df=pd.DataFrame({'인구수':population,'남자인구수':male,'여자인구수':female})
korea_df[1:2]
korea_df
# Out:
#       인구수  남자인구수  여자인구수
# 용인시  1223   1234   1234
# 시흥시  4444   1233   1233
# 수원시  5555    444    444

# %% [markdown]
# # 인덱스 객체

# %% [markdown]
# *   index : 일반적인 index 객체이며, Numpy 배열 형식으로 축의 이름 표현
# *   idx64idex: 정수 값을 위한 index
# * MultiIndex: 단일 축에 여러 단계 색인 을 표현하는 계승적 Index 객체
# * DatatimeIndex:Numpy 의 datatime64 타입으로 타임스탬프 저장
# * PeriodIndex : 기간 데이터를 위한 Index

# %%
idx= pd.Index([2,4,6,8,10])
idx
# Out:
# Index([2, 4, 6, 8, 10], dtype='int64')

# %%
idx[1]
# Out:
# 4

# %%
#시작점, 끝점, 건너뛰는 칸
idx[1:5:2]
# Out:
# Index([4, 8], dtype='int64')

# %%
idx[-1::]
# Out:
# Index([10], dtype='int64')

# %%
idx[::2]
# Out:
# Index([2, 6, 10], dtype='int64')

# %%
print(idx)
print(idx.size)
# 차원 , 축
print(idx.shape)
# 1차원
print(idx.ndim)
# Out:
# Index([2, 4, 6, 8, 10], dtype='int64')
# 5
# (5,)
# 1

# %%
idx1= pd.Index([1,2,3,4,5])
idx2=pd.Index([5,6,7,8,9])
print(idx1.append(idx2))
#차집합
print(idx1.difference(idx2))

print(idx1.intersection(idx2))

print(idx1.union(idx2))
print(idx1.drop(1))
print(idx1 ^ idx2)
# Out:
# Index([1, 2, 3, 4, 5, 5, 6, 7, 8, 9], dtype='int64')
# Index([1, 2, 3, 4], dtype='int64')
# Index([5], dtype='int64')
# Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64')
# Index([2, 3, 4, 5], dtype='int64')
# Index([4, 4, 4, 12, 12], dtype='int64')

# %% [markdown]
# # 인덱싱

# %%
s=pd.Series([0,0.25,0.5,0.75,1.0],index=['a','b','c','d','e'])
s
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
'b' in s
# Out:
# True

# %%
s.keys()
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
list(s.items())
# Out:
# [('a', 0.0), ('b', 0.25), ('c', 0.5), ('d', 0.75), ('e', 1.0)]

# %%
s[0:4]
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# dtype: float64

# %%
# 특정 조건만 주어져서, 값을 추출
s[(s>0.4)&(s<0.8)]
# Out:
# c    0.50
# d    0.75
# dtype: float64

# %% [markdown]
# # Series 인덱싱

# %%
s=pd.Series(['a','b','c','d','e'],index=[1,3,5,7,9])
s
# Out:
# 1    a
# 3    b
# 5    c
# 7    d
# 9    e
# dtype: object

# %%
#iloc 은 0 부터 시작
s.iloc[1]
# Out:
# 'b'

# %%
s.iloc[2:4]
# Out:
# 5    c
# 7    d
# dtype: object

# %%
# 다시 인덱스를 재배치하고, 없는 값은 b  로 채운다.
s.reindex(range(10),method='bfill')
# Out:
# 0    a
# 1    a
# 2    b
# 3    b
# 4    c
# 5    c
# 6    d
# 7    d
# 8    e
# 9    e
# dtype: object

# %%
s[1]
# Out:
# 'a'

# %%
korea_df['남여비율']=(korea_df['남자인구수']*100/korea_df['여자인구수'])

# %%
korea_df.values
# Out:
# array([[1223., 1234., 1234.,  100.],
#        [4444., 1233., 1233.,  100.],
#        [5555.,  444.,  444.,  100.]])

# %%
korea_df
# Out:
#       인구수  남자인구수  여자인구수  남여 비율
# 용인시  1223   1234   1234  100.0
# 시흥시  4444   1233   1233  100.0
# 수원시  5555    444    444  100.0

# %%
korea_df['남자인구수']
# Out:
# 용인시    1234
# 시흥시    1233
# 수원시     444
# Name: 남자인구수, dtype: int64

# %%
korea_df.남자인구수
# Out:
# 용인시    1234
# 시흥시    1233
# 수원시     444
# Name: 남자인구수, dtype: int64

# %%
korea_df.여자인구수
# Out:
# 용인시    1234
# 시흥시    1233
# 수원시     444
# Name: 여자인구수, dtype: int64

# %%
korea_df.남여비율
# Out:
# 용인시    100.0
# 시흥시    100.0
# 수원시    100.0
# Name: 남여비율, dtype: float64

# %%
korea_df.T
# Out:
#           용인시     시흥시     수원시
# 인구수    1223.0  4444.0  5555.0
# 남자인구수  1234.0  1233.0   444.0
# 여자인구수  1234.0  1233.0   444.0
# 남여 비율   100.0   100.0   100.0
# 남여비율    100.0   100.0   100.0

# %%
korea_df['인구수']
# Out:
# 용인시    1223
# 시흥시    4444
# 수원시    5555
# Name: 인구수, dtype: int64

# %%
korea_df.loc[:"수원시",'남자인구수':]
# Out:
#      남자인구수  여자인구수  남여 비율   남여비율
# 용인시   1234   1234  100.0  100.0
# 시흥시   1233   1233  100.0  100.0
# 수원시    444    444  100.0  100.0

# %%
korea_df.loc[korea_df.여자인구수>1000]
# Out:
#       인구수  남자인구수  여자인구수  남여 비율   남여비율
# 용인시  1223   1234   1234  100.0  100.0
# 시흥시  4444   1233   1233  100.0  100.0

# %% [markdown]
# # 다중 인덱스 Series

# %% [markdown]
# * 1차원의 Series 와 2 차원의 DataFrame 객체를 넘어, 3차원 4차원 이상의 고차원 데이터 처리

# %%
korea_df
# Out:
#       인구수  남자인구수  여자인구수  남여 비율   남여비율
# 용인시  1223   1234   1234  100.0  100.0
# 시흥시  4444   1233   1233  100.0  100.0
# 수원시  5555    444    444  100.0  100.0

# %%
idx_tuples=[('용인시',2010),('용인시',2015),('시흥시',2010),('시흥시',2015),('수원시',2010),('수원시',2015)]
idx_tuples
# Out:
# [('용인시', 2010),
#  ('용인시', 2015),
#  ('시흥시', 2010),
#  ('시흥시', 2015),
#  ('수원시', 2010),
#  ('수원시', 2015)]

# %%
pop_tuples=[1234,3333,
            2222,3434,
            23223,1112]
population=pd.Series(pop_tuples,index=idx_tuples)
population
# Out:
# (용인시, 2010)     1234
# (용인시, 2015)     3333
# (시흥시, 2010)     2222
# (시흥시, 2015)     3434
# (수원시, 2010)    23223
# (수원시, 2015)     1112
# dtype: int64

# %% [markdown]
# MultiIndex 가 뭐야?

# %%
midx=pd.MultiIndex.from_tuples(idx_tuples)
midx
# Out:
# MultiIndex([('용인시', 2010),
#             ('용인시', 2015),
#             ('시흥시', 2010),
#             ('시흥시', 2015),
#             ('수원시', 2010),
#             ('수원시', 2015)],
#            )

# %%
population=population.reindex(midx)
population
# Out:
# 용인시  2010     1234
#      2015     3333
# 시흥시  2010     2222
#      2015     3434
# 수원시  2010    23223
#      2015     1112
# dtype: int64

# %%
population[:,2010]
# Out:
# 용인시     1234
# 시흥시     2222
# 수원시    23223
# dtype: int64

# %%
population['용인시',:]
# Out:
# 2010    1234
# 2015    3333
# dtype: int64

# %%
population.unstack()
# Out:
#       2010  2015
# 수원시  23223  1112
# 시흥시   2222  3434
# 용인시   1234  3333

# %%
male_tuple=[15667,2367,
            5678,4544,
            1233,66567]
male_tuple
# Out:
# [15667, 2367, 5678, 4544, 1233, 66567]

# %%
korea_mdf=pd.DataFrame({'총인구수':population,'남자인구수':male_tuple})
korea_mdf
# Out:
#            총인구수  남자인구수
# 용인시 2010   1234  15667
#     2015   3333   2367
# 시흥시 2010   2222   5678
#     2015   3434   4544
# 수원시 2010  23223   1233
#     2015   1112  66567

# %%
female_tuple=[15667,2367,
            5678,4544,
            1233,66567]
female_tuple
# Out:
# [15667, 2367, 5678, 4544, 1233, 66567]

# %%
korea_mdf=pd.DataFrame({'총인구수':population,'남자인구수':male_tuple,'여자인구수':female_tuple})
korea_mdf
# Out:
#            총인구수  남자인구수  여자인구수
# 용인시 2010   1234  15667  15667
#     2015   3333   2367   2367
# 시흥시 2010   2222   5678   5678
#     2015   3434   4544   4544
# 수원시 2010  23223   1233   1233
#     2015   1112  66567  66567

# %%
ratio=korea_mdf['남자인구수']*100/korea_mdf['여자인구수']
korea_mdf=pd.DataFrame({'총인구수':population,'남자인구수':male_tuple,'여자인구수':female_tuple,'비율':ratio})
korea_mdf
ratio
# Out:
#       2010   2015
# 수원시  100.0  100.0
# 시흥시  100.0  100.0
# 용인시  100.0  100.0

# %% [markdown]
# # 데이터 연산

# %%
# '+' 연산 : 없는 index 은 NaN 값으로 들어간다.
s1= pd.Series([7.3,-2.5,3.4,1.5],index=['a','c','d','e'])
s2=pd.Series([1,2,3,4],index=['a','b','c','e'])
s1+s2
# Out:
# a    8.3
# b    NaN
# c    0.5
# d    NaN
# e    5.5
# dtype: float64

# %%
# 없는 것이 0으로 처리되어 0+num 처리
s1.add(s2,fill_value=0)
# Out:
# a    8.3
# b    2.0
# c    0.5
# d    3.4
# e    5.5
# dtype: float64

# %%
df1=pd.DataFrame(np.random.randint(0,20,(3,3)),
                 columns=list('ACD'))
df1
# Out:
#     A   C   D
# 0   7  13  11
# 1   9   9  14
# 2  12   3   2

# %%
df2=pd.DataFrame(np.random.randint(0,20,(5,5)),
                 columns=list('ACDED'))
df2
# Out:
#     A   C   D   E   D
# 0  10  18  16  11   0
# 1  14   1   2  16   8
# 2  17   7  18  12  12
# 3   0  11  10   0  17
# 4  16  15   9   2   9

# %%
df1+df2
# Out:
#       A     C     D     D   E
# 0  17.0  31.0  27.0  11.0 NaN
# 1  23.0  10.0  16.0  22.0 NaN
# 2  29.0  10.0  20.0  14.0 NaN
# 3   NaN   NaN   NaN   NaN NaN
# 4   NaN   NaN   NaN   NaN NaN

# %%
fvalue=df1.stack().mean()
df1.add(df2,fill_value=fvalue)
# Out:
#            A          C          D          D          E
# 0  17.000000  31.000000  27.000000  11.000000  19.888889
# 1  23.000000  10.000000  16.000000  22.000000  24.888889
# 2  29.000000  10.000000  20.000000  14.000000  20.888889
# 3   8.888889  19.888889  18.888889  25.888889   8.888889
# 4  24.888889  23.888889  17.888889  17.888889  10.888889

# %% [markdown]
# # 순위

# %%
s=pd.Series([-2,4,5,1,2,5,6,3])
s
# Out:
# 0   -2
# 1    4
# 2    5
# 3    1
# 4    2
# 5    5
# 6    6
# 7    3
# dtype: int64

# %%
s.rank()
# Out:
# 0    1.0
# 1    5.0
# 2    6.5
# 3    2.0
# 4    3.0
# 5    6.5
# 6    8.0
# 7    4.0
# dtype: float64

# %% [markdown]
# # 고성능 연산

# %%
nrows, ncols=10000,100
df1,df2,df3,df4=(pd.DataFrame(np.random.rand(nrows,ncols)) for i in range(4))
df1
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.012729  0.924332  0.753081  0.667432  0.060863  0.786080  0.609820
# 1     0.396786  0.142817  0.972476  0.893611  0.279711  0.035172  0.108900
# 2     0.390602  0.715628  0.570155  0.546386  0.952279  0.723812  0.441705
# 3     0.349171  0.474640  0.977052  0.778177  0.394051  0.090448  0.828675
# 4     0.673501  0.570165  0.517038  0.687611  0.287645  0.453774  0.891987
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.033280  0.744892  0.420192  0.466057  0.851511  0.998379  0.506973
# 9996  0.499389  0.424325  0.022226  0.621810  0.752051  0.718613  0.694153
# 9997  0.381682  0.030028  0.863969  0.311625  0.522058  0.754140  0.759148
# 9998  0.224793  0.491464  0.344077  0.159735  0.538459  0.711361  0.345158
# 9999  0.331783  0.256160  0.850713  0.065455  0.726949  0.674092  0.821518
#
#             7         8         9   ...        90        91        92  \
# 0     0.898626  0.746218  0.828515  ...  0.050994  0.556135  0.083763
# 1     0.381485  0.964940  0.747475  ...  0.267493  0.770951  0.383199
# 2     0.747070  0.676737  0.085843  ...  0.463597  0.911994  0.922041
# 3     0.512611  0.349836  0.258306  ...  0.066265  0.755910  0.583031
# 4     0.699887  0.946408  0.382943  ...  0.669188  0.420232  0.035082
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995  0.454613  0.819887  0.142761  ...  0.593170  0.585879  0.349222
# 9996  0.729684  0.949302  0.031588  ...  0.869570  0.086613  0.302117
# 9997  0.188221  0.557929  0.890538  ...  0.784807  0.072091  0.564631
# 9998  0.605260  0.144130  0.744516  ...  0.231635  0.868727  0.748608
# 9999  0.193131  0.333705  0.669441  ...  0.177833  0.585048  0.796203
#
#             93        94        95        96        97        98        99
# 0     0.078360  0.971131  0.218359  0.696838  0.545486  0.958616  0.212599
# 1     0.306029  0.180154  0.248851  0.631410  0.376309  0.097928  0.447948
# 2     0.038525  0.825104  0.580304  0.747374  0.280494  0.816448  0.667623
# 3     0.009113  0.929587  0.842012  0.246947  0.592812  0.804237  0.193647
# 4     0.399327  0.468705  0.421975  0.285684  0.970707  0.934243  0.815908
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.776554  0.469581  0.143593  0.001689  0.918628  0.691776  0.436152
# 9996  0.400028  0.932327  0.666031  0.188240  0.444322  0.330104  0.804147
# 9997  0.679962  0.180228  0.270876  0.098026  0.831868  0.094812  0.201107
# 9998  0.404301  0.465185  0.296742  0.449756  0.962369  0.141573  0.390180
# 9999  0.020914  0.511811  0.249060  0.840571  0.343351  0.904564  0.465415
#
# [10000 rows x 100 columns]

# %%
# %timeit df1+df2+df3+df4
# Out:
# 14.4 ms ± 615 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit pd.eval('df1+df2+df3+df4')
# Out:
# 7.15 ms ± 1.43 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df=pd.DataFrame(np.random.rand(100000,5),columns=['A','B','C','D','E'])
# %timeit df['A']+df['B']+df['C']+df['D']+df['E']
# Out:
# 2.49 ms ± 1.07 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit pd.eval('df.A+df.B+df.C+df.D+df.E')
# Out:
# 2.86 ms ± 78.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
